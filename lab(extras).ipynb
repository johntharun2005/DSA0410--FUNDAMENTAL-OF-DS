# %%
# Data Science Lab Manual

## Week 1
### 1a. Create a list, manipulate and slice it.
```python
my_list = [10, 20, 30, 40, 50]
print("Original List:", my_list)
my_list.append(60)
print("After Append:", my_list)
my_list[2] = 35
print("After Update:", my_list)
print("Sliced List (2 to 4):", my_list[2:5])
list1 = [1, 2, 3]
list2 = [4, 5, 6]
combined = list1 + list2
print("Combined List:", combined)
matrix = [list1, list2]
print("Matrix:", matrix)
my_tuple = (10, 20, 30, 40, 50)
print("Tuple:", my_tuple)
print("Sliced Tuple (1 to 4):", my_tuple[1:5])
my_dict = {"a": 1, "b": 2}
my_dict["c"] = 3
print("Dictionary:", my_dict)
print("Keys:", list(my_dict.keys()))
print("Values:", list(my_dict.values()))
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Marks': [85, 90, 88]}
df = pd.DataFrame(data)
print("DataFrame:\n", df)
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
area = [694, 905, 802, 1366, 716, 963, 821, 714, 1018, 887, 790, 696, 771, 1006, 1191]
price = [192.0, 215.0, 215.0, 274.0, 112.7, 185.0, 212.0, 220.0, 276.0, 260.0, 221.5, 255.0, 260.0, 293.0, 375.0]
df = pd.DataFrame({"Area": area, "Price": price})
plt.scatter(df['Area'], df['Price'])
plt.title("Price vs Area")
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()
plt.hist(df['Price'], bins=10)
plt.title("Histogram of Sale Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()
log_price = np.log(df['Price'])
plt.scatter(df['Area'], log_price)
plt.title("Log Price vs Area")
plt.xlabel("Area")
plt.ylabel("Log(Price)")
plt.show()
outliers = df[df['petal length (cm)'] > 1.5 * avg_petal_length]
print("Petal Length Outliers:\n", outliers)
print("Standard Deviation by Species:\n", df.groupby('species').std())
def outliers_by_species(group):
    avg = group['petal length (cm)'].mean()
    return group[group['petal length (cm)'] > 1.5 * avg]
species_outliers = df.groupby('species').apply(outliers_by_species)
print("Outliers by Species:\n", species_outliers)
import pandas as pd
import numpy as np
iris_df = pd.DataFrame({
    'sepal length (cm)': [5.1, 4.9, np.nan, 4.6, 5.0],
    'sepal width (cm)': [3.5, np.nan, 3.2, 3.1, 3.6],
    'petal length (cm)': [1.4, 1.4, 1.3, np.nan, 1.5],
    'petal width (cm)': [0.2, 0.2, 0.2, 0.2, np.nan],
})
iris_df.fillna(iris_df.mean(), inplace=True)
print("Iris Dataset after filling missing values:\n", iris_df)
import matplotlib.pyplot as plt
import numpy as np
people = ['G1','G2','G3','G4','G5','G6','G7','G8']
data = np.array([
 [3.4, 7.7, 6.4, 10.5, 7.5, 7.1, 12.8, 3.4],
 [11.2, 5.0, 6.7, 12.3, 7.5, 6.8, 7.2, 3.7],
 [3.9, 4.7, 11.7, 4.6, 13.0, 4.6, 11.2, 8.6],
 [4.2, 12.7, 11.4, 9.0, 10.5, 11.0, 4.0, 8.8],
])
ind = np.arange(len(people))
width = 0.5
bottom = np.zeros(len(people))
for i in range(data.shape[0]):
    plt.bar(ind, data[i], width, bottom=bottom, label=f'Segment {i+1}')
    for j in range(len(people)):
        plt.text(j, bottom[j] + data[i][j]/2, f"{data[i][j]:.1f}", ha='center', va='center', fontsize=7)
    bottom += data[i]
plt.ylabel('Scores')
plt.title('Scores by Group and Segment')
plt.xticks(ind, people)
plt.legend()
plt.show()
